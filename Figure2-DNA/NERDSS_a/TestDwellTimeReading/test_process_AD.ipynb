# %%
import numpy as np
from matplotlib import pyplot as plt
import sys
sys.path.append('../../../')
from process_AD import readResT_from_NERDSS

# %%
help(readResT_from_NERDSS)
# Out:
# Help on function readResT_from_NERDSS in module process_AD:
#
# readResT_from_NERDSS(file_assoc_dissoc_times: str, dt: float, proteins=['P'], substrates=['S', 'N'], debug: bool = False, startT: float = 0)
#     Read residence time and search time from assoc_dissoc_time.dat. Return numpy arrays of residence time and search time
#
#     Input:
#         file_assoc_dissoc_times: path to assoc_dissoc_time.dat
#         dt: time step (s)
#         proteins: list of protein names
#         substrates: list of substrate names
#         debug: print out the information of each protein
#     Output:
#         resTimesAll: numpy array of residence time
#         searchTimesAll: numpy array of search time

# %%
resT, searchT = readResT_from_NERDSS('./fake_assoc_dissoc.dat', dt=1, debug=True, startT=10)
# Out:
# ITR:0,BOND,P,0,2,P,1,2
# rxnPRO ('P', '0', 'P', '1', 'BOND', 0.0)
# 0 startT: -1.000 endT: -1.000
# 1 startT: -1.000 endT: -1.000
# ITR:1,BOND,N,202,0,P,0,0
# rxnSUB ('P', '0', 'N', '202', 'BOND', 1.0)
# startT: 1.000 endT: -1.000
# startT: 1.000 endT: -1.000
# ITR:2,BREAK,N,202,0,P,0,0
# rxnSUB ('P', '0', 'N', '202', 'BREAK', 2.0)
# startT: -1.000 endT: 2.000
# startT: -1.000 endT: 2.000
# ITR:11,BOND,N,102,0,P,0,0
# rxnSUB ('P', '0', 'N', '102', 'BOND', 11.0)
# startT: 11.000 endT: -1.000
# startT: 11.000 endT: -1.000
# ITR:15,BOND,N,33,0,P,1,0
# rxnSUB ('P', '1', 'N', '33', 'BOND', 15.0)
# startT: 11.000 endT: -1.000
# startT: 11.000 endT: -1.000
# ITR:20,BREAK,N,33,0,P,1,0
# rxnSUB ('P', '1', 'N', '33', 'BREAK', 20.0)
# startT: 11.000 endT: -1.000
# startT: 11.000 endT: -1.000
# ITR:21,BREAK,N,102,0,P,0,0
# rxnSUB ('P', '0', 'N', '102', 'BREAK', 21.0)
# startT: -1.000 endT: 21.000
# startT: -1.000 endT: 21.000
# ITR:101,BOND,N,100,0,P,0,0
# ...

# %%
assert (np.unique(resT) == np.array([1.0, 10.0, 29.0, 50.0])).all()

# %%
resT
# Out:
# array([ 1., 10., 29., 50.,  1., 10., 29., 50.])
